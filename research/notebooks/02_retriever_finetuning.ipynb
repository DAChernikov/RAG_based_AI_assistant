# %% [markdown]
# # Opt-in retriever fine-tuning
# Keep train/validation/test splits isolated and compare held-out metrics.

# %%
RUN_TRAINING = False
SEED = 42
TRAIN_FRACTION = 0.7
VALIDATION_FRACTION = 0.15
LOCAL_WEIGHTS_DIR = '../models/finetuned-retriever'

# %%
if RUN_TRAINING:
    # Load the model and training libraries only after explicit opt-in.
    # Split by query id before constructing examples; never use test labels for tuning.
    raise NotImplementedError('Configure an approved dataset before local training.')
else:
    print('Training disabled. No models are downloaded and no weights are written.')
